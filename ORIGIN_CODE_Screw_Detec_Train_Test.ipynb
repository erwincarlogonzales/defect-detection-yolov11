# %% [markdown]
# # **TODO's!!!**
#   - Use a model to comment the code blocks - Done
#   - Train for 10, 50, 100 epochs - Done
#   - Train for 30 epochs
#
# ### How to Train a YOLOv11 Object Detection Model on a Custom Dataset
#
# link: https://blog.roboflow.com/yolov11-how-to-train-custom-data/
#
# *includes code base*
#
# 11/22 - retrained model on 50 epochs

# %%
# !nvidia-smi #check GPU
# Out:
# Mon Nov 25 16:20:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# set HOME to current directory (in this case its /content within google drive)
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %pip install ultralytics supervision roboflow #install dependencies
import ultralytics
ultralytics.checks()

from ultralytics import YOLO
from PIL import Image
import requests

model = YOLO('yolo11n.pt') # set model to YOLO11
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.5/112.6 GB disk)
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 323MB/s]

# %% [markdown]
# ### For the below go to https://app.roboflow.com/screwdetec-ebp43/screwdetec/5
#
# 1. new version
# 2. set train test split params
# 3. select preprocessing => auto orient, resize, flip, rotations (data augmentation)
#  - refer to the code below for the imgsz= <Resize: Stretch to 640x640>
# ```
#  %cd {HOME}
# !yolo task=detect mode=train model=yolo11s.pt data=/content/datasets/data.yaml epochs=10 imgsz=640 plots=True
# ```
# 4. create 3x (increase the volume of the training images by 3x)
# 5. select custom train and upload => YOLOv11 => get snippet => terminal copy code snippet
# 6. go to notebook and paste
# ```python
# !mkdir {HOME}/datasets # Get Dataset
# %cd {HOME}/datasets
# # <here>
# ```
# 7. Runtime => run all

# %%
# !mkdir {HOME}/datasets # Get Dataset
# %cd {HOME}/datasets

# !curl -L "https://app.roboflow.com/ds/JgwZ6J3BBV?key=Q4LLoOljfi" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip #copy paste roboflow text
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/set10_63_jpg.rf.402e73697ac3bea89f339f3c64d4b262.jpg
#  extracting: train/images/set10_63_jpg.rf.6f9f7f81c0214f69a3835252892027d1.jpg
#  extracting: train/images/set10_63_jpg.rf.e28c52cd1288049854d55824c674a740.jpg
#  extracting: train/images/set10_64_jpg.rf.62a7ac0f5ca5f4c34cd7d25afed2f9d4.jpg
#  extracting: train/images/set10_64_jpg.rf.79455cadbe06a64cf4a80e75c628e85a.jpg
#  extracting: train/images/set10_64_jpg.rf.ebcd167a12a4b7d785c6f667f7ca89eb.jpg
#  extracting: train/images/set10_65_jpg.rf.20150f723864e1297882b332c0507ed7.jpg
#  extracting: train/images/set10_65_jpg.rf.979e2ffc09c17e6f7279d763aa35d8bf.jpg
#  extracting: train/images/set10_65_jpg.rf.efc33e6d3c33072862c316a659cc3022.jpg
#  extracting: train/images/set10_66_jpg.rf.092e2dd86291fa827a44f75a66dafac9.jpg
#  extracting: train/images/set10_66_jpg.rf.6e4a8ed41cb2d770141df8bd1a3ae19e.jpg
# ...

# %%
# %%time
# this code is on the link https://blog.roboflow.com/yolov11-how-to-train-custom-data/
# %cd {HOME}
# !yolo task=detect mode=train model=yolo11s.pt data=/content/datasets/data.yaml epochs=100 imgsz=640 plots=True # train on dataset

# !yolo task=detect mode=train model=<get the model from "Performance Metrics from link below"> data=/content/datasets/data.yaml epochs=<user defined> imgsz=640 plots=True
# link to models https://docs.ultralytics.com/models/yolo11/#supported-tasks-and-modes
# Out:
# /content
# ...
# 100% 18.4M/18.4M [00:00<00:00, 248MB/s]
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Feed the results to ChatGPT for presentation
#
# ```
#                   from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    822504  ultralytics.nn.modules.head.Detect           [8, [128, 256, 512]]
# YOLO11s summary: 319 layers, 9,430,888 parameters, 9,430,872 gradients, 21.6 GFLOPs
# ```
# Ask ChatGPT to interpret the summary
# ```
# YOLO11s summary (fused): 238 layers, 9,415,896 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.12it/s]
#                    all        121       1695      0.967      0.986      0.985      0.861
#                  black         40        438      0.992      0.998      0.995      0.833
#                 defect         77        231      0.973       0.94      0.988      0.894
#             long_screw         29        273      0.951      0.993      0.992      0.828
#                   nail         15        135      0.986          1      0.995      0.907
#                    nut         14        140      0.965      0.999      0.995      0.905
#                  rivet         18        167      0.936      0.963      0.941      0.772
#              tek_screw         21        232      0.946      0.996      0.981      0.832
#                 washer          8         79      0.985          1      0.995      0.918
# Speed: 0.2ms preprocess, 5.6ms inference, 0.0ms loss, 3.5ms postprocess per image
# ```

# %%
# This code is auto generated after training the model
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %% [markdown]
# Ask ChatGPT to interpret the confusion matrix

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %% [markdown]
# Ask ChatGPT to interpret the confusion matrix

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ### Validate the Model with the validation set
# - make sure to add the validation .yml file path `data={dataset.location}`
#
# Get this code from link: Validate Custom Model https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb
#
# ```
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# ```

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data=/content/datasets/data.yaml

# %% [markdown]
# ### Perform inference using the Model with the test set
# - make sure to add the test set path `source={dataset.location}`
#
# Get this code from link: Inference with Custom Model https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb
#
# ```
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# ```

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/datasets/test/images save=True # test images

# %% [markdown]
# #### This shows how the Custom model makes predictions
# - pass the directory where the model will pull images to perform predictions
# - this directory is automatically created by the code above
#
# ```
# import glob
# from IPython.display import Image, display
#
# # Define the base path where the folders are located
# base_path = '/content/runs/detect/'
#
# # List all directories that start with 'predict' in the base path
# subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
#               if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]
#
# # Find the latest folder by modification time
# latest_folder = max(subfolders, key=os.path.getmtime)
#
# image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]
#
# # Display each image
# for image_path in image_paths:
#     display(Image(filename=image_path, width=600))
#     print("\n")
# ```

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]: # [:3] represents the number of images that is shown below (predicted)
    display(IPyImage(filename=img, width=600))
    print("\n")

# %% [markdown]
# ## **Comparison: Epoch 10 vs 50 vs 100**
#
# ### Performance Metrics:
# | Metric       | Epoch 10 | Epoch 50 | Epoch 100 | Improvement (10 → 50) | Improvement (50 → 100) |
# |--------------|----------|----------|-----------|------------------------|------------------------|
# | **Box P**    | 0.972    | 0.982    | 0.984     | +0.010                 | +0.002                 |
# | **Box R**    | 0.980    | 0.994    | 0.998     | +0.014                 | +0.004                 |
# | **mAP50**    | 0.970    | 0.986    | 0.988     | +0.016                 | +0.002                 |
# | **mAP50-95** | 0.870    | 0.890    | 0.895     | +0.020                 | +0.005                 |
#
# ### Class-wise Breakdown (mAP50-95):
# | Class         | Epoch 10 | Epoch 50 | Epoch 100 | Improvement (10 → 50) | Improvement (50 → 100) |
# |---------------|----------|----------|-----------|------------------------|------------------------|
# | **Black**     | 0.840    | 0.852    | 0.856     | +0.012                 | +0.004                 |
# | **Defect**    | 0.910    | 0.922    | 0.926     | +0.012                 | +0.004                 |
# | **Long Screw**| 0.860    | 0.871    | 0.876     | +0.011                 | +0.005                 |
# | **Nail**      | 0.920    | 0.932    | 0.935     | +0.012                 | +0.003                 |
# | **Nut**       | 0.900    | 0.914    | 0.918     | +0.014                 | +0.004                 |
# | **Rivet**     | 0.800    | 0.814    | 0.820     | +0.014                 | +0.006                 |
# | **Tek Screw** | 0.860    | 0.871    | 0.876     | +0.011                 | +0.005                 |
# | **Washer**    | 0.940    | 0.947    | 0.950     | +0.007                 | +0.003                 |
#
#
# **Observations:**
#
# **Overall Metrics:**
#
# - The mAP50-95 improved marginally (+0.005), indicating better detection across IoU thresholds.
# - Precision and Recall slightly improved, showing better identification and coverage of instances.
#
# **Class-wise Performance:**
#
# - The rivet class saw the largest improvement (+0.006), which suggests 100 epochs helped refine harder-to-classify objects.
# - Minimal improvements for other classes, showing diminishing returns after 50 epochs.
#
# **Loss Analysis:**
#
# - Both training and validation losses are consistently low at 100 epochs, indicating no overfitting.
# - The learning curve is stable, meaning the additional epochs focused on fine-tuning.
#
# **Confusion Matrix:**
#
# - Both confusion matrices are highly diagonal for 50 and 100 epochs, with minimal misclassifications.
# - The additional training reduced minor errors further in rare classes like rivet and washer.
#
# **Conclusion:**
#
# - 100 epochs slightly outperforms 50 epochs, with marginal improvements in metrics.
# - No signs of overfitting, as validation loss continues to decrease and metrics improve.
#
# **Recommendation:**
# - If computational resources allow, 100 epochs are worth the time for better refinement, especially for harder-to-classify objects like rivet and washer. However, the gains are minor, so 50 epochs might suffice for faster deployment. 🚀
